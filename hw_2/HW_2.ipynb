# %% [markdown]
# ## Условие 1: 1 задача

# %% [markdown]
# ### Скачать данные kc_house_data (см. вложения)
# Считать д`анные с помощью pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# ### Вывести на экран первые 5 строк

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.sample()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 15073  8825900020  20140811T000000  925000.0         5        3.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15073         2710      4200     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 15073        1890            820      1919          2014    98115  47.6754
#
#           long  sqft_living15  sqft_lot15
# 15073 -122.307           2150        4200
#
# [1 rows x 21 columns]

# %% [markdown]
# ### Посмотреть на описание признаков и на их содержание

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ## Условие 2: 2 задача

# %% [markdown]
# ### Проведите первичный анализ данных

# %% [markdown]
# ### Изучите типы данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ### Найдите количество пропущенных ячеек в данных

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# Пустых ячеек нет

# %% [markdown]
# ### Посчитайте основные статистики по всем признакам и поизучайте их

# %%
df.describe().round(2)
# Out:
#                  id       price  bedrooms  bathrooms  sqft_living    sqft_lot  \
# count  2.161300e+04    21613.00  21613.00   21613.00     21613.00    21613.00
# mean   4.580302e+09   540088.14      3.37       2.11      2079.90    15106.97
# std    2.876566e+09   367127.20      0.93       0.77       918.44    41420.51
# min    1.000102e+06    75000.00      0.00       0.00       290.00      520.00
# 25%    2.123049e+09   321950.00      3.00       1.75      1427.00     5040.00
# 50%    3.904930e+09   450000.00      3.00       2.25      1910.00     7618.00
# 75%    7.308900e+09   645000.00      4.00       2.50      2550.00    10688.00
# max    9.900000e+09  7700000.00     33.00       8.00     13540.00  1651359.00
#
#          floors  waterfront      view  condition     grade  sqft_above  \
# count  21613.00    21613.00  21613.00   21613.00  21613.00    21613.00
# mean       1.49        0.01      0.23       3.41      7.66     1788.39
# ...

# %% [markdown]
# ## Условие 3: 3 задача

# %% [markdown]
# ### 3.1 В каком диапазоне изменяются стоимости недвижимости?

# %%
df_price_min=df['price'].min()
df_price_max=df['price'].max()
print(df_price_min, df_price_max)
# Out:
# 75000.0 7700000.0

# %% [markdown]
# От 75 000 до 7 700 000 единиц цены

# %% [markdown]
# ### 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?

# %%
df['living_sqrt_percent'] = df["sqft_living"] / df["sqft_lot"]
df['living_sqrt_percent'].mean()
# Out:
# 0.32374472542047195

# %% [markdown]
# В среднем жилая площадь занимает 32,3 %

# %% [markdown]
# ### 3.3 Как много домов с разными этажами в данных?

# %%
df['floors'].nunique()
# Out:
# 6

# %%
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %% [markdown]
# 6 видов домов с разными этажами

# %% [markdown]
# ### 3.4 Насколько хорошие состояния у домов в данных

# %%
print(df['condition'].min())
print(df['condition'].max())
print(df['condition'].mean())
print(df['condition'].median())
# Out:
# 1
# 5
# 3.4094295100171195
# 3.0

# %% [markdown]
# Дома оцениваются по пятибальной системе, в среднем дома имеют оценку 3,4. Медианное значение -3 балла

# %% [markdown]
# ### 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %%
print(df['yr_built'].min())
print(df['yr_built'].max())
# Out:
# 1900
# 2015

# %% [markdown]
# В данных дома от 1900 до 2015 года постройки

# %% [markdown]
# ## Условие 4: 4 задача

# %% [markdown]
# ### 4.1 Сколько в среднем стоят дома, у которых 2 спальни?

# %%
mean_price_bedrooms=df[df['bedrooms']== 2 ]['price'].mean()
mean_price_bedrooms
# Out:
# 401372.681884058

# %% [markdown]
# Дома с двумя спальнями стоят 401372,68

# %% [markdown]
# ### 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
mean_sqrt_price=df[df['price'] > 600000 ]['sqft_lot'].mean()
mean_sqrt_price
# Out:
# 20442.524776214832

# %% [markdown]
# Дома с ценой больше 600000 имеют среднюю площадь 20442,52

# %% [markdown]
# ### 4.3 Как много домов коснулся ремонт?

# %%
renov= df[~(df['yr_renovated'] == 0)]['yr_renovated'].count()
renov
# Out:
# 914

# %% [markdown]
# 914 домов имеют ремонт

# %% [markdown]
# ### 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %%
grade10= df[(df['grade'] > 10)]['price'].mean()
grade4= df[(df['grade'] < 4)]['price'].mean()
grade10/grade4
# Out:
# 8.846561884215443

# %% [markdown]
# В среднем цена различается в 8,84 раза

# %% [markdown]
# ## Условие 5: 5 задача

# %% [markdown]
# ### 5.1 Выберите дом клиенту
# Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?

# %%
df[ (df["bathrooms"] > 2) &
    (df["waterfront"] == 1) &
    (df["sqft_basement"] > 0)
]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 457    2122039094  20141126T000000   705000.0         3       3.00
# 656    3760500116  20141120T000000  3070000.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 18914  9253900408  20150408T000000  1400000.0         3       2.75
# 20325   518500480  20140811T000000  3000000.0         3       3.50
# 20767  8043700105  20150417T000000  2300000.0         4       4.00
# 21201   518500460  20141008T000000  2230000.0         3       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 49            2753     65005     1.0           1     2  ...        2165
# ...

# %% [markdown]
# У клиента 76 вариантов

# %% [markdown]
# ### 5.2 Выберите дом клиенту
# Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?

# %%
df_max = df[
    ((df["waterfront"] == 1) | (df["view"] == 4)) &
    (df["condition"] > 4.5) &
    (df["yr_built"] > 1978)
]['price'].max()

df_min = df[
    ((df["waterfront"] == 1) | (df["view"] == 4)) &
    (df["condition"] > 4.5) &
    (df["yr_built"] > 1978)
]['price'].min()

print(df_min, df_max)
# Out:
# 1295000.0 3000000.0

# %% [markdown]
# Цена домов будет от 1295000 до 3000000

# %% [markdown]
# ### 5.3 Выберите дом клиенту
# Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %%
condition = df[
    (df["sqft_basement"] == 0) &
    (df["floors"] ==2) &
    (df["price"] < 150000)
]['condition'].mean()
condition
# Out:
# 2.8333333333333335

# %% [markdown]
# Такие дома имеют оценку 2.83 по состоянию
